# %%
import requests

# %%
url = "https://realtor.p.rapidapi.com/properties/list-for-sale"

# https://rapidapi.com/apidojo/api/realtor/endpoints

querystring = {"sort":"relevance","radius":"10","offset":"0","limit":"1000","postal_code":"80202"}

# city - The value of city field responded in locations/auto-complete API (do not use this parameter with postal_code)
# offset - The offset of items to be ignored in response for paging
# limit - The number of items to be responded in every request
# state code - The value of state_code field responded in locations/auto-complete API (do not use this parameter with postal_code)
## postal code - Zip code or postal code (do not use this parameter with city and state_code)

headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': "aaf97ab322msh634818fa34ec594p1b03e3jsnaf892e7d4ed3"
    }

# 500 Calls a month

response = requests.request("GET", url, headers=headers, params=querystring).json()

# %%
listing = response["address"]
listing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-16ea9a916c3c> in <module>
# ----> 1 listing = response["address"]
#       2 listing
#
# TypeError: list indices must be integers or slices, not str

# %%
addresscount=-1
addresses = []
for address in listings:
    addresscount = addresscount+1
    address = listings[addresscount]["address"]
    addresses.append(address)
addresses
# Out:
# ['261 Central Ave Apt E1 in Lawrence, Lawrence, 11559',
#  '50 E 72nd St Unit 10A in Lenox Hill, New York, 10021',
#  '300 E 40th St Apt 4W in Murray Hill, New York, 10016',
#  '41-31 51st St Unit 5F in Woodside, Woodside, 11377',
#  '478 E 53rd St in East Flatbush, Brooklyn, 11203',
#  '118-51 226th St in Cambria Heights, Cambria Heights, 11411',
#  '209-80 18th Ave Unit 6E in Bay Terrace, Bayside, 11360',
#  '721 Shepherd Ave in New Lots, New York, 11208',
#  '2 W 90th St Apt 2D in Upper West Side, New York, 10024',
#  '21-28 45th Rd Unit 4 in Long Island City, Queens, 11101',
#  '60 E 8th St Apt 27A in Downtown Manhattan, New York, 10003',
#  '850 Metropolitan Ave Unit 4E in East Williamsburg, Brooklyn, 11211',
#  '440 Fanning St in Manor Heights, Staten Island, 10314',
#  '450 W 17th St Apt 2203 in Midtown Manhattan, New York, 10011',
#  '3945 Wilder Ave in Edenwald, Bronx, 10466',
#  '197 N Railroad St in Huguenot, Staten Island, 10312',
#  '98 Front St Ph 1J in DUMBO, Brooklyn, 11201',
#  '98 Front St Ph 3H in DUMBO, Brooklyn, 11201',
#  '52 E End Ave Apt 11C in Upper East Side, New York, 10028',
#  '155 E 49th St Unit 6B in Turtle Bay, New York, 10017',
#  '78-10 34th Ave Unit 2C in Jackson Heights, Queens, 11372',
#  '425 Prospect Pl Apt 1H in Prospect Heights, New York, 11238',
#  '200 E 24th St Units 1201 & 02 in Midtown Manhattan, New York, 10010',
#  '98 Front St Unit 9C in DUMBO, Brooklyn, 11201',
#  '320 E 42nd St Apt 1112 in Tudor City, New York, 10017',
#  '245 E 87th St Apt 7G in Yorkville, New York, 10128',
#  '2 River Ter Apt 4D in Battery Park City, New York, 10282',
#  '52 E End Ave Unit 11A in Upper East Side, New York, 10028',
#  '10 Park Ave Unit 17E in Murray Hill, New York, 10016',
#  '78-10 34th Ave Unit 5J in Jackson Heights, Queens, 11372',
#  '134 W 93rd St Apt 1A in Upper West Side, New York, 10025',
#  '121 E 22nd St Unit Sph in Midtown Manhattan, New York, 10010',
#  '250 E 53rd St Apt 2504 in Turtle Bay, New York, 10022',
#  '6 Hastings Lndg in South Ardsley, Hastings On Hudson, 10706',
#  '617A Prospect Ave Unit A, Fairview, 07022',
#  '2611 Avenue U in Madison, Brooklyn, 11229',
#  '128 W Kingsbridge Rd in Parkside, Mount Vernon, 10550',
#  '3 Southview Ct in North Hempstead, Carle Place, 11514',
#  '412 Hillside Dr in North Hempstead, New Hyde Park, 11040',
#  '68 Austin Ave, Old Bridge, 08857',
#  '8 Opal St in Elmont, Elmont, 11003',
#  '104-45 209th St in Queens Village, Queens Village, 11429',
#  '63-27 253 St in Little Neck, Little Neck, 11362',
#  '8030 221st St in Bayside, Hollis Hills, 11427',
#  '350 W 71st St Unit 6B in Upper West Side, Manhattan, 10023',
#  '150 Rivington St Apt 6B in Downtown Manhattan, Manhattan, 10002',
#  '1450 Pacific St in Crown Heights, Brooklyn, 11216',
#  '205 W End Ave Apt 23K in Upper West Side, New York, 10023',
#  '208 Java St Unit 2 in Greenpoint, Brooklyn, 11222',
#  '110 Justin Ave in Bay Terrace, Staten Island, 10306',
#  '11 Hoyt St Unit 10F in Downtown Brooklyn, New York, 11201',
#  '11 Hoyt St Unit 20H in Downtown Brooklyn, New York, 11201',
#  '12 Shorecliff Pl in Harbor Hills, Great Neck, 11023',
#  '518 Beach 139th St Apt A6 in Rockaway Peninsula, Belle Harbor, 11694',
#  '39 Jackson Ave, Rockville Centre, 11570',
#  '103-08 Corona Ave in South Corona, Corona, 11368',
#  '53-18 69th St in Maspeth, Maspeth, 11378',
#  '915 Logan Ave in Throgs Neck, Bronx, 10465',
#  '1600 Center Ave Apt 4E, Fort Lee, 07024',
#  '25 McKinley Pl in Greenburgh, Ardsley, 10502',
#  '1530 Palisade Ave Apt 6L, Fort Lee, 07024',
#  '800 Ave at Port Imperial Blvd Apt 605, Weehawken, 07086',
#  '1071 Lafayette St in Midtown Elizabeth, Elizabeth City, 07201',
#  '191 Withers St Unit 3L in Williamsburg, Brooklyn, 11211',
#  '539 Hart St Unit 3 in Bushwick, Brooklyn, 11221',
#  '389 E 89th St Apt 12C in Yorkville, Manhattan, 10128',
#  '20 Pine St Apt 1713, Manhattan, 10005',
#  '138 E Broadway Unit 10A in Downtown Manhattan, Manhattan, 10002',
#  '182-184 E 2nd St Unit 1E in Downtown Manhattan, Manhattan, 10009',
#  '800 Ave at Port Imperial Blvd Apt 1014, Weehawken, 07086',
#  '14-15 Sunnyside Ave in Bayswater, Far Rockaway, 11691',
#  '290 Candon Ave in Rossville, Staten Island, 10309',
#  '424 E 115th St Apt 2B in East Harlem, New York, 10029',
#  '62 Sterling Ave, Weehawken, 07086',
#  '414 41st St in Sunset Park, Brooklyn, 11232',
#  '156 Nesbit St, Weehawken, 07086',
#  '1521 Bantam Pl in Pelham Gardens, Bronx, 10469',
#  '260-61 75th Ave in Glen Oaks Village Section 2, Glen Oaks, 11004',
#  '2475 E 11th St Apt 4E in Sheepshead Bay, Brooklyn, 11235',
#  '231 Geneva St in Frog Hollow, Elizabeth City, 07206',
#  '7227 Kennedy Blvd in Transfer Station, North Bergen, 07047',
#  '260-14 83rd Ave in Floral Park, Floral Park, 11004',
#  '147-10 73rd Ave in Kew Gardens Hills, Kew Gardens Hills, 11367',
#  '617 11th St in South Slope, Brooklyn, 11215',
#  '79 Zabriskie Ave in Bergen Point, Bayonne, 07002',
#  '919 E 224th St in Wakefield, Bronx, 10466',
#  '11 Hoyt St Unit 16B in Downtown Brooklyn, New York, 11201',
#  '40 E 75th St in Upper East Side, New York, 10021',
#  '11 Hoyt St Unit 15H in Downtown Brooklyn, New York, 11201',
#  '350 W 42nd St Apt 15L in Garment District, New York, 10036',
#  '11 Hoyt St Unit 25K in Downtown Brooklyn, New York, 11201',
#  '11 Hoyt St Unit 7L in Downtown Brooklyn, New York, 11201',
#  '150 E 83rd St Apt 3C in Upper East Side, New York, 10028',
#  '2800 Coyle St Apt 408 in Sheepshead Bay, Brooklyn, 11235',
#  '445 E 86th St Unit 3AB in Upper East Side, Manhattan, 10028',
#  '285 5th Ave Apt 2A in Central Slope, Brooklyn, 11215',
#  '1117 79th St in Transfer Station, North Bergen, 07047',
#  '45 River Dr S Apt 406 in The Waterfront, Jersey City, 07310',
#  '75-15 210th St Unit 5A in Oakland Gardens, Bayside, 11364',
#  '101 Vernon Ave, Atlantic Beach, 11509',
#  '520 Christopher Ave in Brownsville, Brooklyn, 11212',
#  '112 Sunset Blvd Unit 11112 in Harding Park, Bronx, 10473',
#  '41 Cypress Ave, Oceanside, 11572',
#  'Melrose, South Amboy, 08879',
#  '100 Romer Rd in Todt Hill, Staten Island, 10304',
#  '18 Eagan Ave in Annadale, Staten Island, 10312',
#  '267 Hosmer Ave in Throgs Neck, Bronx, 10465',
#  '9 Beacon Ter, Keansburg, 07734',
#  '16 Russell Ct, Matawan, 07747',
#  '1543 W 1st St Apt F9 in Bensonhurst, Brooklyn, 11204',
#  '35 Rumson Rd in Mid-Island, Staten Island, 10314',
#  '38 Silver Ct in Silver Lake, Staten Island, 10301',
#  '9 Dreyer Ave in Mid-Island, Staten Island, 10314',
#  '2 Spruce St Apt 4G in Thomaston, Great Neck, 11021',
#  '59 Parkview Pl, Malverne, 11565',
#  '70-75 E Park Dr Unit A in Kew Gardens Hills, Flushing, 11367',
#  '8 E 83rd St Unit 9C in Upper East Side, New York, 10028',
#  '120 E 87th St Apt R24A in Upper East Side, New York, 10128',
#  '8 E 83rd St Units 11 & 12D in Upper East Side, New York, 10028',
#  '477 Fdr Dr Apt M902 in Downtown Manhattan, New York, 10002',
#  '3850 Hudson Manor Ter Apt 4BW in Riverdale, Bronx, 10463',
#  '102 Columbus Dr Apt 808 in Harsimus, Jersey City, 07302',
#  '2475 E 11th St Apt 3K in Sheepshead Bay, Brooklyn, 11235',
#  '7 Putnam Rd in Greenacres, Scarsdale, 10583',
#  '153 Smith St Apt F2, Freeport, 11520',
#  '70-25 Yellowstone Blvd Unit 2H in Forest Hills, Forest Hills, 11375',
#  '559 Fairview Ave in Ridgewood, Ridgewood, 11385',
#  '131-05 40 Rd Ph 3Q in Flushing, Flushing, 11354',
#  '12 High Elms Ln, Glen Cove, 11542',
#  '76 Schermerhorn St Unit 9C in Boerum Hill, Brooklyn, 11201',
#  '200 E 24th St Units 807 & 808 in Midtown Manhattan, Manhattan, 10010',
#  '1363 Hancock St in Bushwick, Brooklyn, 11237',
#  '4 W 16th St Apt 5A in Union Square, Manhattan, 10011',
#  '399 Taylor Ave, Hackensack, 07601',
#  '1769 E 91st St in Canarsie, Brooklyn, 11236',
#  '47-03 88th St in Elmhurst, Elmhurst, 11373',
#  '135-33 Cheney St in St. Albans, Springfield Gardens, 11413',
#  '109-33 213th St in Bellaire Estates, Queens Village, 11429',
#  '141 1/2 Louis Ave in Elmont, Elmont, 11003',
#  '80-32 161 St in Hillcrest, Hillcrest, 11432',
#  '16 Pheasant Run in North Hempstead, Old Westbury, 11568',
#  '111 Roff Ave, Palisades Park, 07650',
#  '415 Roff Ave Apt A, Palisades Park, 07650',
#  '2015 E 61st St in Mill Basin, Brooklyn, 11234',
#  '1360 Ocean Pkwy Apt 5D in Central Brooklyn, Brooklyn, 11230',
#  '445 72nd St in Bay Ridge, Brooklyn, 11209',
#  '28 Bay 49th St in Gravesend, Brooklyn, 11214',
#  '1834 85th St in Bensonhurst, Brooklyn, 11214',
#  '270 Rice Ave in Castleton Corners, Staten Island, 10314',
#  '673 Pelham Rd Apt E16 in South Side, New Rochelle, 10805',
#  '117 Ogden Ave Apt 3L in The Heights, Jersey City, 07307',
#  '1170 Ocean Pkwy Ph C in Central Brooklyn, Brooklyn, 11230',
#  '1 Carousel Ln in Lido Beach, Lido Beach, 11561',
#  '31-22 80 St in Jackson Heights, Jackson Heights, 11370',
#  '1075 Sheepshead Bay Rd Apt 5F in Sheepshead Bay, Brooklyn, 11229',
#  '186 Calhoun Ave in Throgs Neck, Bronx, 10465',
#  '710 Cambridge Ave, Union Beach, 07735',
#  '1433 E 27th St in Midwood, Brooklyn, 11210',
#  '929 Marginal Rd in Lido Beach, Lido Beach, 11561',
#  '275 Engle St Apt A5 in East Hill, Englewood, 07631',
#  '1019 78th St in Dyker Heights, Brooklyn, 11228',
#  '715 Prospect St Apt B5, Baldwin, 11510',
#  '177-30 145th Dr in Springfield Gardens, Jamaica, 11434',
#  '50 Shore Blvd Apt 4K in Manhattan Beach, Brooklyn, 11235',
#  '6 Birchwood Ct Apt 4F in North Hempstead, Mineola, 11501',
#  '148 E 84th St Apt 2B in Upper East Side, New York, 10028',
#  '50 E 89th St Unit 9G in Upper East Side, Manhattan, 10128',
#  '50 Pine Island Ter in Laurence Harbor, Old Bridge, 07735',
#  '176 Brooklyn Ave Lot 6, Spotswood, 08884',
#  '59 Cornwells Beach Rd in Sands Point, Sands Point, 11050',
#  '111-09 66th Ave Unit 2B in Forest Hills, Forest Hills, 11375',
#  '43 Livingston Ave, Avenel, 07001',
#  '425 E 58th St Apt 21C in Sutton Place, New York, 10022',
#  '11 E 36th St Rm 1101 in Midtown Manhattan, New York, 10016',
#  '11 E 36th St Ste 1204 in Midtown Manhattan, New York, 10016',
#  '160 W End Ave Apt 9H in Upper West Side, New York, 10023',
#  '388 Bridge St Apt 33H in Downtown Brooklyn, Brooklyn, 11201',
#  '25 Charles St Apt 5E in West Village, New York, 10014',
#  '15 W 11th St Apt 6A in Downtown Manhattan, New York, 10011',
#  '300 E 85th St Apt 2704 in Upper East Side, New York, 10028',
#  '2 Horatio St Apt 16M in West Village, New York, 10014',
#  '188 E 70th St Apt 20A in Upper East Side, New York, 10021',
#  '52 Gunton Pl in Rossville, Staten Island, 10309',
#  '180 Manhattan St in South Shore, Staten Island, 10307',
#  '9 Huguenot Dr, Larchmont, 10538',
#  '124 Richbell Rd Apt B2, Mamaroneck, 10543',
#  '48 Main St, Little Ferry, 07643',
#  '1025 Maxwell Ln Apt 902 in North East Hoboken, Hoboken, 07030',
#  '1188 E 55th St in Flatlands, Brooklyn, 11234',
#  '221 Logan St in Highland Park, Brooklyn, 11208',
#  '5730 Mosholu Ave Apt 2C in North Riverdale, Bronx, 10471',
#  '27 Berry Ct in Rossville, Staten Island, 10309',
#  '169 Silver Lake Rd in North Shore, Staten Island, 10301',
#  '3 Somerset Ln Apt 424, Edgewater, 07020',
#  '184 Wardwell Rd in North Hempstead, Mineola, 11501',
#  '476 Morristown Rd Lot 35, Old Bridge, 07747',
#  '112 Devonshire Rd in Forest Knolls, Larchmont, 10538',
#  '1987 Grand Ave in Morris Heights, Bronx, 10453',
#  '1077 River Rd Apt 311, Edgewater, 07020',
#  '68 E Hartsdale Ave Apt 5K in Greenburgh, Hartsdale, 10530']
