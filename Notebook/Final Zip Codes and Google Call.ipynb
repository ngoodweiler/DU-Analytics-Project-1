# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
#Import zipcode key csv file
zip_code_csv = "../Resources/zip_code_database.csv"

# %%
#Create Original DataFrame, replace na with blank stings
zip_code_df = pd.read_csv(zip_code_csv)
zip_code_df = zip_code_df.replace(np.nan, '', regex=True)

# %%
#Filter on just Colorado Zip Codes and sort by population, take top 25 most populated zips in CO
co_zip_code = zip_code_df.loc[(zip_code_df["Include?"] != ""),:]
co_zip_code = co_zip_code[["zip","latitude","longitude"]]
co_zip_code = co_zip_code.set_index("zip")
co_zip_code.to_csv("../Resources/25 Final Zip Codes.csv")

# %%
# gmaps heatmaps for restaurants
import gmaps
import requests
import json
from pprint import pprint

restaurant_key = 'AIzaSyD642sjE_Th8vphxZtWe2NHsiFalPc2K-U'
# Configure gmaps
gmaps.configure(api_key=restaurant_key)

# Restaurant df creation
restaurant_df = co_zip_code
restaurant_df = restaurant_df.reset_index()
restaurant_df.to_csv('../Resources/zip_lat_lng.csv')

# %%
zipcode_dict = {}

# Generate dictionary of json data from each zipcode
for i in range(0,25):
    zipcode = restaurant_df.iloc[i,0]
    lat = restaurant_df.iloc[i,1]
    lng = restaurant_df.iloc[i,2]
    # geocoordinates
    target_coordinates = f"{lat},{lng}"
    target_radius = 5000
    target_type = "restaurant"    

    # set up a parameters dictionary
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": target_coordinates,
        "radius": target_radius,
        "type": target_type,
        "key": restaurant_key,
    }
    
    # assemble url and make API request
    response = requests.get(base_url, params=params)
    content = json.loads(response.content)

    # create a dictionary of dataframes for each i
    zipcode_dict[i] = {i: pd.DataFrame.from_dict(content['results'])}

# %%
# zipcode_dict works as a dictionary of dataframes, select which zipcode by [i]
# where i is the index value from the co_zip_codes
# further, to extract required data, you must use zipcode_dict[i][i]['key']

# %%
restaurant_df = co_zip_code
restaurant_df = restaurant_df.reset_index()
restaurant_summary = restaurant_df
zipcode_dict
# Out:
# {0: {0:                                              geometry  \
#   0   {'location': {'lat': 39.7966522, 'lng': -105.0...
#   1   {'location': {'lat': 39.802305, 'lng': -105.08...
#   2   {'location': {'lat': 39.7696876, 'lng': -105.0...
#   3   {'location': {'lat': 39.769164, 'lng': -105.07...
#   4   {'location': {'lat': 39.7970106, 'lng': -105.0...
#   5   {'location': {'lat': 39.7907862, 'lng': -105.0...
#   6   {'location': {'lat': 39.79078620000001, 'lng':...
#   7   {'location': {'lat': 39.79076939999999, 'lng':...
#   8   {'location': {'lat': 39.8004311, 'lng': -105.1...
#   9   {'location': {'lat': 39.8132251, 'lng': -105.0...
#   10  {'location': {'lat': 39.7639387, 'lng': -105.1...
#   11  {'location': {'lat': 39.7702362, 'lng': -105.1...
#   12  {'location': {'lat': 39.7816189, 'lng': -105.0...
#   13  {'location': {'lat': 39.769658, 'lng': -105.07...
#   14  {'location': {'lat': 39.79998729999999, 'lng':...
#   15  {'location': {'lat': 39.796527, 'lng': -105.07...
#   16  {'location': {'lat': 39.800495, 'lng': -105.08...
#   17  {'location': {'lat': 39.7931077, 'lng': -105.0...
#   18  {'location': {'lat': 39.7870129, 'lng': -105.1...
#   19  {'location': {'lat': 39.8173461, 'lng': -105.0...
#
#                                                    icon  \
#   0   https://maps.gstatic.com/mapfiles/place_api/ic...
#   1   https://maps.gstatic.com/mapfiles/place_api/ic...
#   2   https://maps.gstatic.com/mapfiles/place_api/ic...
#   3   https://maps.gstatic.com/mapfiles/place_api/ic...
#   4   https://maps.gstatic.com/mapfiles/place_api/ic...
#   5   https://maps.gstatic.com/mapfiles/place_api/ic...
#   6   https://maps.gstatic.com/mapfiles/place_api/ic...
#   7   https://maps.gstatic.com/mapfiles/place_api/ic...
#   8   https://maps.gstatic.com/mapfiles/place_api/ic...
#   9   https://maps.gstatic.com/mapfiles/place_api/ic...
#   10  https://maps.gstatic.com/mapfiles/place_api/ic...
#   11  https://maps.gstatic.com/mapfiles/place_api/ic...
#   12  https://maps.gstatic.com/mapfiles/place_api/ic...
#   13  https://maps.gstatic.com/mapfiles/place_api/ic...
#   14  https://maps.gstatic.com/mapfiles/place_api/ic...
#   15  https://maps.gstatic.com/mapfiles/place_api/ic...
#   16  https://maps.gstatic.com/mapfiles/place_api/ic...
#   17  https://maps.gstatic.com/mapfiles/place_api/ic...
#   18  https://maps.gstatic.com/mapfiles/place_api/ic...
#   19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                             id  \
#   0   82d6aaf7ec44f97a69d2de5ffd6099ac78e8bbb5
#   1   68651d4197215af836551214cf68ef67811b3635
#   2   a4215a18c94778d84db5b7b177cb51f9e64054c0
#   3   148e4c91ff1781af034384d30ff1329df6d425e1
#   4   fdaef789275a246d4a8c9e2af7694c2143ef86b8
#   5   258981772f97e6a6d86282071791b651f42b2350
#   6   133cc0826d47a727e347afc68d815ff0b02b5a19
#   7   6afde07953865011a0447f423b15bc5677275472
#   8   dd7e54cb6aecdec0bef21cc2ecb5ec9576df8859
#   9   a4f7dc11e1f33fec6448a3b3303e99b916513c6f
#   10  67091e6da6c6a5513b33bdf889747a4ec62884da
#   11  d3e3d62c74793395afbe873d79ea76a78b0502ef
#   12  1b6256ceae7ae2c3261a20a96b9278069eeae51d
#   13  bdcf0e8f5a861dfd251709578016ea6f3b0a41b3
#   14  8aef009b5799bbcead93d7889b308a5c93d9295c
#   15  b56fffc6698232d52275c995482ac574a5719625
#   16  36bb4800322b43b46ef8dc8d8e7702f6568734d4
#   17  13ac5c74544781235d64013f17702b87a0d569b4
#   18  8dc348e1b77eadddf5d5c677e333e31b7abe01b7
#   19  555a6bcb632cb35022a997ab2f5455a1cad42ecb
#
#                                      name        opening_hours  \
#   0                       Texas Roadhouse   {'open_now': True}
#   1   Yak and Yeti Restaurant and Brewpub   {'open_now': True}
#   2                  Little Caesars Pizza   {'open_now': True}
#   3                        Sunrise Sunset  {'open_now': False}
#   4                 Einstein Bros. Bagels  {'open_now': False}
#   5                                Subway   {'open_now': True}
#   6          Namiko's Japanese Restaurant   {'open_now': True}
#   7   Red Robin Gourmet Burgers and Brews   {'open_now': True}
#   8                                Subway   {'open_now': True}
#   9                                Subway   {'open_now': True}
#   10                          Smashburger   {'open_now': True}
#   11     Large Marges Philly Cheesesteaks   {'open_now': True}
#   12        El Paraiso Mexican Restaurant   {'open_now': True}
#   13  Colorado Plus Brew Pub and Taphouse   {'open_now': True}
#   14        Santiago's Mexican Restaurant   {'open_now': True}
#   15                         Ruby Tuesday   {'open_now': True}
#   16                    The Arvada Tavern   {'open_now': True}
#   17                     Beau Jo's Arvada   {'open_now': True}
#   18                Luke's, A Steak Place   {'open_now': True}
#   19             Golden Europe Restaurant   {'open_now': True}
#
#                                                  photos  \
#   0   [{'height': 270, 'html_attributions': ['<a hre...
#   1   [{'height': 608, 'html_attributions': ['<a hre...
#   2   [{'height': 3072, 'html_attributions': ['<a hr...
#   3   [{'height': 1363, 'html_attributions': ['<a hr...
#   4   [{'height': 289, 'html_attributions': ['<a hre...
#   5                                                 NaN
#   6   [{'height': 389, 'html_attributions': ['<a hre...
#   7   [{'height': 608, 'html_attributions': ['<a hre...
#   8   [{'height': 2340, 'html_attributions': ['<a hr...
#   9   [{'height': 720, 'html_attributions': ['<a hre...
#   10  [{'height': 1080, 'html_attributions': ['<a hr...
#   11  [{'height': 4032, 'html_attributions': ['<a hr...
#   12  [{'height': 615, 'html_attributions': ['<a hre...
#   13  [{'height': 1536, 'html_attributions': ['<a hr...
#   14  [{'height': 1080, 'html_attributions': ['<a hr...
#   15  [{'height': 1960, 'html_attributions': ['<a hr...
#   16  [{'height': 1280, 'html_attributions': ['<a hr...
#   17  [{'height': 400, 'html_attributions': ['<a hre...
#   18  [{'height': 2269, 'html_attributions': ['<a hr...
#   19  [{'height': 2988, 'html_attributions': ['<a hr...
#
#                          place_id  \
#   0   ChIJt_BPVC2Ga4cRgXscsUD_N_U
#   1   ChIJIZOu6SuGa4cRh4xAPHPxHZ0
#   2   ChIJIXgKb1SGa4cR3HdqK-s330I
#   3   ChIJ6TKz1VSGa4cRFLMce8WjUyo
#   4   ChIJLz9srtKHa4cRpb5P3-Zlv1o
#   5   ChIJ3yeALsuHa4cRjyFsuoDaHMU
#   6   ChIJ3yeALsuHa4cRb_DIs5mwsNE
#   7   ChIJ4VacTcuHa4cRc_BFCN4L-Fk
#   8   ChIJbSePlh-Ga4cR1IYTM3T2fN8
#   9   ChIJMcZKaoeIa4cRGrzf3PhCWAI
#   10  ChIJ9w_Tu86Fa4cRRn7pR8Jw1oA
#   11  ChIJGb1t0GWGa4cR4UEhnvOuzcs
#   12  ChIJQQMQhLuHa4cRIqBuHbUvokI
#   13  ChIJu-cAy6uHa4cRa0dFGugQq_I
#   14  ChIJtTswEx-Ga4cRZvZlx7QSXLQ
#   15  ChIJR3gRWM2Ha4cR5XVwyVp-o1s
#   16  ChIJ97TdiCyGa4cRbL0dR-b7ogo
#   17  ChIJAexs4PiIa4cRYHRp5qqymJQ
#   18  ChIJBSfh8BOGa4cRtJMQTxIBJog
#   19  ChIJHfk_bIiIa4cR91HqVO4w7zY
#
#                                               plus_code  price_level  rating  \
#   0   {'compound_code': 'QWWC+M4 Arvada, Colorado, U...            2     4.4
#   1   {'compound_code': 'RW28+W8 Arvada, Colorado, U...            2     4.6
#   2   {'compound_code': 'QW98+VH Wheat Ridge, Colora...            1     4.0
#   3   {'compound_code': 'QW9C+M8 Wheat Ridge, Colora...            1     4.4
#   4   {'compound_code': 'QWWC+RG Arvada, Colorado, U...            1     3.7
#   5   {'compound_code': 'QWRC+8Q Arvada, Colorado, U...            1     3.5
#   6   {'compound_code': 'QWRC+8V Arvada, Colorado, U...            2     4.5
#   7   {'compound_code': 'QWRC+8F Arvada, Colorado, U...            2     3.9
#   8   {'compound_code': 'RV2W+5W Arvada, Colorado, U...            1     3.4
#   9   {'compound_code': 'RW7C+78 Arvada, Colorado, U...            1     4.2
#   10  {'compound_code': 'QV75+H5 Wheat Ridge, Colora...            2     4.2
#   11  {'compound_code': 'QVCR+3F Wheat Ridge, Colora...            1     4.6
#   12  {'compound_code': 'QWJQ+J4 Wheat Ridge, Colora...            2     3.8
#   13  {'compound_code': 'QW9G+V8 Wheat Ridge, Colora...            2     4.5
#   14  {'compound_code': 'QVXW+XC Arvada, Colorado, U...            1     4.1
#   15  {'compound_code': 'QWWC+JQ Arvada, Colorado, U...            2     3.7
#   16  {'compound_code': 'RW29+59 Arvada, Colorado, U...            2     4.6
#   17  {'compound_code': 'QWVC+6F Arvada, Colorado, U...            2     4.3
#   18  {'compound_code': 'QVPR+RH Wheat Ridge, Colora...            2     4.3
#   19  {'compound_code': 'RW89+WJ Arvada, Colorado, U...            2     4.7
#
#                         reference   scope  \
#   0   ChIJt_BPVC2Ga4cRgXscsUD_N_U  GOOGLE
#   1   ChIJIZOu6SuGa4cRh4xAPHPxHZ0  GOOGLE
#   2   ChIJIXgKb1SGa4cR3HdqK-s330I  GOOGLE
#   3   ChIJ6TKz1VSGa4cRFLMce8WjUyo  GOOGLE
#   4   ChIJLz9srtKHa4cRpb5P3-Zlv1o  GOOGLE
#   5   ChIJ3yeALsuHa4cRjyFsuoDaHMU  GOOGLE
#   6   ChIJ3yeALsuHa4cRb_DIs5mwsNE  GOOGLE
#   7   ChIJ4VacTcuHa4cRc_BFCN4L-Fk  GOOGLE
#   8   ChIJbSePlh-Ga4cR1IYTM3T2fN8  GOOGLE
#   9   ChIJMcZKaoeIa4cRGrzf3PhCWAI  GOOGLE
#   10  ChIJ9w_Tu86Fa4cRRn7pR8Jw1oA  GOOGLE
#   11  ChIJGb1t0GWGa4cR4UEhnvOuzcs  GOOGLE
#   12  ChIJQQMQhLuHa4cRIqBuHbUvokI  GOOGLE
#   13  ChIJu-cAy6uHa4cRa0dFGugQq_I  GOOGLE
#   14  ChIJtTswEx-Ga4cRZvZlx7QSXLQ  GOOGLE
#   15  ChIJR3gRWM2Ha4cR5XVwyVp-o1s  GOOGLE
#   16  ChIJ97TdiCyGa4cRbL0dR-b7ogo  GOOGLE
#   17  ChIJAexs4PiIa4cRYHRp5qqymJQ  GOOGLE
#   18  ChIJBSfh8BOGa4cRtJMQTxIBJog  GOOGLE
#   19  ChIJHfk_bIiIa4cR91HqVO4w7zY  GOOGLE
#
#                                                   types  user_ratings_total  \
#   0   [bar, restaurant, food, point_of_interest, est...                2821
#   1   [bar, restaurant, food, point_of_interest, est...                1920
#   2   [meal_takeaway, restaurant, food, point_of_int...                 278
#   3   [restaurant, food, point_of_interest, establis...                 525
#   4   [bakery, cafe, restaurant, food, point_of_inte...                 189
#   5   [meal_takeaway, restaurant, food, point_of_int...                  87
#   6   [restaurant, food, point_of_interest, establis...                 422
#   7   [restaurant, food, point_of_interest, establis...                1106
#   8   [meal_takeaway, restaurant, food, point_of_int...                  25
#   9   [meal_takeaway, restaurant, food, point_of_int...                  91
#   10  [restaurant, food, point_of_interest, establis...                 316
#   11  [meal_takeaway, restaurant, food, point_of_int...                 605
#   12  [restaurant, food, point_of_interest, establis...                1367
#   13  [art_gallery, bar, restaurant, food, point_of_...                 411
#   14  [restaurant, food, point_of_interest, establis...                 995
#   15  [bar, restaurant, food, point_of_interest, est...                 963
#   16  [night_club, bar, restaurant, food, point_of_i...                 887
#   17  [bar, restaurant, food, point_of_interest, est...                1855
#   18  [restaurant, food, point_of_interest, establis...                 296
#   19  [restaurant, food, point_of_interest, establis...                 446
#
#                                    vicinity
#   0               5515 Vance Street, Arvada
#   1               7803 Ralston Road, Arvada
#   2      7777 West 38th Avenue, Wheat Ridge
#   3      7400 West 38th Avenue, Wheat Ridge
#   4    5545 Wadsworth Bypass unit b, Arvada
#   5        7310 West 52nd Avenue #C, Arvada
#   6    7310 West 52nd Avenue unit R, Arvada
#   7           7460 West 52nd Avenue, Arvada
#   8               9400 Ralston Road, Arvada
#   9        6406 Wadsworth Boulevard, Arvada
#   10    3356 Youngfield Street, Wheat Ridge
#   11       3890 Kipling Street, Wheat Ridge
#   12  4690 North Harlan Street, Wheat Ridge
#   13     6995 West 38th Avenue, Wheat Ridge
#   14          9575 West 57th Avenue, Arvada
#   15          5525 Wadsworth Bypass, Arvada
#   16  5707 Olde Wadsworth Boulevard, Arvada
#   17          7525 West 53rd Avenue, Arvada
#   18    4990 Kipling Street #1, Wheat Ridge
#   19       6620 Wadsworth Boulevard, Arvada  },
#  1: {1:                                              geometry  \
#   0   {'location': {'lat': 39.86052999999999, 'lng':...
#   1   {'location': {'lat': 39.7966522, 'lng': -105.0...
#   2   {'location': {'lat': 39.802305, 'lng': -105.08...
#   3   {'location': {'lat': 39.861225, 'lng': -105.05...
#   4   {'location': {'lat': 39.8570274, 'lng': -105.0...
#   5   {'location': {'lat': 39.8411646, 'lng': -105.0...
#   6   {'location': {'lat': 39.853862, 'lng': -105.08...
#   7   {'location': {'lat': 39.854334, 'lng': -105.05...
#   8   {'location': {'lat': 39.861014, 'lng': -105.05...
#   9   {'location': {'lat': 39.8292127, 'lng': -105.0...
#   10  {'location': {'lat': 39.7970106, 'lng': -105.0...
#   11  {'location': {'lat': 39.8132251, 'lng': -105.0...
#   12  {'location': {'lat': 39.8421481, 'lng': -105.0...
#   13  {'location': {'lat': 39.8494378, 'lng': -105.0...
#   14  {'location': {'lat': 39.86198750000001, 'lng':...
#   15  {'location': {'lat': 39.8546355, 'lng': -105.0...
#   16  {'location': {'lat': 39.8677214, 'lng': -105.0...
#   17  {'location': {'lat': 39.86141629999999, 'lng':...
#   18  {'location': {'lat': 39.8334473, 'lng': -105.0...
#   19  {'location': {'lat': 39.86217999999999, 'lng':...
#
#                                                    icon  \
#   0   https://maps.gstatic.com/mapfiles/place_api/ic...
#   1   https://maps.gstatic.com/mapfiles/place_api/ic...
#   2   https://maps.gstatic.com/mapfiles/place_api/ic...
#   3   https://maps.gstatic.com/mapfiles/place_api/ic...
#   4   https://maps.gstatic.com/mapfiles/place_api/ic...
#   5   https://maps.gstatic.com/mapfiles/place_api/ic...
#   6   https://maps.gstatic.com/mapfiles/place_api/ic...
#   7   https://maps.gstatic.com/mapfiles/place_api/ic...
#   8   https://maps.gstatic.com/mapfiles/place_api/ic...
#   9   https://maps.gstatic.com/mapfiles/place_api/ic...
#   10  https://maps.gstatic.com/mapfiles/place_api/ic...
#   11  https://maps.gstatic.com/mapfiles/place_api/ic...
#   12  https://maps.gstatic.com/mapfiles/place_api/ic...
#   13  https://maps.gstatic.com/mapfiles/place_api/ic...
#   14  https://maps.gstatic.com/mapfiles/place_api/ic...
#   15  https://maps.gstatic.com/mapfiles/place_api/ic...
#   16  https://maps.gstatic.com/mapfiles/place_api/ic...
#   17  https://maps.gstatic.com/mapfiles/place_api/ic...
#   18  https://maps.gstatic.com/mapfiles/place_api/ic...
#   19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                             id  \
#   0   e2c7f6301f36ae3b90925912a808d120c53b047e
#   1   82d6aaf7ec44f97a69d2de5ffd6099ac78e8bbb5
#   2   68651d4197215af836551214cf68ef67811b3635
#   3   1027ed81c740002b34b55db7a15e2feaa814e9d0
#   4   360fc9069cba1b67df3aedf3f14610ab1fe01eb5
#   5   811a3299735f555e90346bc1f29a77574c6074f6
#   6   8953905d4dacea074199a0f342400d3afed5eab3
#   7   e82885225e6660b756c1e687fc6d10b798a977c4
#   8   24ecd0f073b41ad73e1ec33fad84ce397ad7b4bf
#   9   2a1e77a9fd1a90d45268485437c1d4ee7c8d9065
#   10  fdaef789275a246d4a8c9e2af7694c2143ef86b8
#   11  a4f7dc11e1f33fec6448a3b3303e99b916513c6f
#   12  d9c2b0f57aa30a3fb85acca33593edadfc4afbe0
#   13  a56bbaa8220fb7802b935d16d1b30f879f0a2719
#   14  3b0d80f0eb06fbcae3e4cf125dd006d77178f752
#   15  6f006dd7375b3dbe2e0df1822f119bcb999177dd
#   16  b68c9ef269064cf2a918e476684c4a2a91339d39
#   17  88f762c08d444b66d1472bb4b86c886ff0405b76
#   18  4e9f336fd69267ff7e8bb920111553006c74e035
#   19  62856c8d52789a3f765ab17ad302d60aa45b57ac
#
#                                           name        opening_hours  \
#   0                           Joe's Crab Shack   {'open_now': True}
#   1                            Texas Roadhouse   {'open_now': True}
#   2        Yak and Yeti Restaurant and Brewpub   {'open_now': True}
#   3                             Sweet Tomatoes   {'open_now': True}
#   4            Olive Garden Italian Restaurant   {'open_now': True}
#   5                         Buffalo Wild Wings   {'open_now': True}
#   6                                Old Chicago   {'open_now': True}
#   7              Yak & Yeti Bar and Restaurant   {'open_now': True}
#   8                      Saltgrass Steak House   {'open_now': True}
#   9                                     Subway   {'open_now': True}
#   10                     Einstein Bros. Bagels  {'open_now': False}
#   11                                    Subway   {'open_now': True}
#   12  Los Arcos Mexican Restaurant Westminster   {'open_now': True}
#   13                  Blackjack Pizza & Salads   {'open_now': True}
#   14                                    Subway   {'open_now': True}
#   15                                    Subway   {'open_now': True}
#   16                     Einstein Bros. Bagels  {'open_now': False}
#   17                                  Hoffbrau   {'open_now': True}
#   18                        DAE GEE KOREAN BBQ   {'open_now': True}
#   19                       Bowlero Westminster   {'open_now': True}
#
#                                                  photos  \
#   0   [{'height': 4032, 'html_attributions': ['<a hr...
#   1   [{'height': 270, 'html_attributions': ['<a hre...
#   2   [{'height': 608, 'html_attributions': ['<a hre...
#   3   [{'height': 2988, 'html_attributions': ['<a hr...
#   4   [{'height': 3024, 'html_attributions': ['<a hr...
#   5   [{'height': 650, 'html_attributions': ['<a hre...
#   6   [{'height': 3120, 'html_attributions': ['<a hr...
#   7   [{'height': 2988, 'html_attributions': ['<a hr...
#   8   [{'height': 315, 'html_attributions': ['<a hre...
#   9   [{'height': 4160, 'html_attributions': ['<a hr...
#   10  [{'height': 289, 'html_attributions': ['<a hre...
#   11  [{'height': 720, 'html_attributions': ['<a hre...
#   12  [{'height': 800, 'html_attributions': ['<a hre...
#   13  [{'height': 1512, 'html_attributions': ['<a hr...
#   14  [{'height': 4032, 'html_attributions': ['<a hr...
#   15  [{'height': 2560, 'html_attributions': ['<a hr...
#   16  [{'height': 3024, 'html_attributions': ['<a hr...
#   17  [{'height': 1836, 'html_attributions': ['<a hr...
#   18  [{'height': 1227, 'html_attributions': ['<a hr...
#   19  [{'height': 3024, 'html_attributions': ['<a hr...
#
#                          place_id  \
#   0   ChIJG8hRgMiJa4cRn19DEOjFVEU
#   1   ChIJt_BPVC2Ga4cRgXscsUD_N_U
#   2   ChIJIZOu6SuGa4cRh4xAPHPxHZ0
#   3   ChIJI8xkMsaJa4cROpMfmmEkarI
#   4   ChIJYeUUWraJa4cRiMlvL9maAxQ
#   5   ChIJ02ehs_yIa4cRdOZTKNcaGBE
#   6   ChIJi20q_waJa4cRF8lgIqUAeyU
#   7   ChIJs4PwTMqJa4cRmFHfIq-aK78
#   8   ChIJQ9b2nsiJa4cRKpnT4bORLf8
#   9   ChIJiQFAmeZ3bIcRswfHfS65OZY
#   10  ChIJLz9srtKHa4cRpb5P3-Zlv1o
#   11  ChIJMcZKaoeIa4cRGrzf3PhCWAI
#   12  ChIJf3HGNjeIa4cREW0q_ru-2VA
#   13  ChIJTe9c3NN3bIcRJ8nYxMPb1kE
#   14  ChIJ1_VX88aJa4cRyrXhCxpFUDM
#   15  ChIJc9QSuweJa4cRUogJjHaMJgY
#   16  ChIJb7ox_sCJa4cRkKXCyVxIlvI
#   17  ChIJNSV6Ss14bIcRLQDrh0B_isI
#   18  ChIJJwXpIz-Ia4cRsQPJd_w4o0U
#   19  ChIJK2RLebmJa4cRVV33IAdmHNo
#
#                                               plus_code  price_level  rating  \
#   0   {'compound_code': 'VW6W+6W Westminster, Colora...          2.0     4.1
#   1   {'compound_code': 'QWWC+M4 Arvada, Colorado, U...          2.0     4.4
#   2   {'compound_code': 'RW28+W8 Arvada, Colorado, U...          2.0     4.6
#   3   {'compound_code': 'VW6X+F2 Westminster, Colora...          1.0     4.3
#   4   {'compound_code': 'VW4R+RW Westminster, Colora...          2.0     4.1
#   5   {'compound_code': 'RWR5+FQ Arvada, Colorado, U...          2.0     3.4
#   6   {'compound_code': 'VW39+G3 Westminster, Colora...          2.0     4.0
#   7   {'compound_code': 'VW3V+PW Westminster, Colora...          2.0     4.4
#   8   {'compound_code': 'VW6X+C6 Westminster, Colora...          2.0     4.3
#   9   {'compound_code': 'RXHG+M6 Westminster, Colora...          1.0     3.3
#   10  {'compound_code': 'QWWC+RG Arvada, Colorado, U...          1.0     3.7
#   11  {'compound_code': 'RW7C+78 Arvada, Colorado, U...          1.0     4.2
#   12  {'compound_code': 'RWRX+VR Westminster, Colora...          2.0     4.2
#   13  {'compound_code': 'RXXG+QV Westminster, Colora...          1.0     3.4
#   14  {'compound_code': 'VW6X+Q3 Westminster, Colora...          1.0     3.0
#   15  {'compound_code': 'VW39+VG Arvada, Colorado, U...          1.0     3.3
#   16  {'compound_code': 'VW9X+32 Westminster, Colora...          1.0     4.1
#   17  {'compound_code': 'VW6C+H2 Westminster, Colora...          2.0     4.2
#   18  {'compound_code': 'RWMX+92 Arvada, Colorado, U...          2.0     4.4
#   19  {'compound_code': 'VW6Q+VC Westminster, Colora...          NaN     4.1
#
#                         reference   scope  \
#   0   ChIJG8hRgMiJa4cRn19DEOjFVEU  GOOGLE
#   1   ChIJt_BPVC2Ga4cRgXscsUD_N_U  GOOGLE
#   2   ChIJIZOu6SuGa4cRh4xAPHPxHZ0  GOOGLE
#   3   ChIJI8xkMsaJa4cROpMfmmEkarI  GOOGLE
#   4   ChIJYeUUWraJa4cRiMlvL9maAxQ  GOOGLE
#   5   ChIJ02ehs_yIa4cRdOZTKNcaGBE  GOOGLE
#   6   ChIJi20q_waJa4cRF8lgIqUAeyU  GOOGLE
#   7   ChIJs4PwTMqJa4cRmFHfIq-aK78  GOOGLE
#   8   ChIJQ9b2nsiJa4cRKpnT4bORLf8  GOOGLE
#   9   ChIJiQFAmeZ3bIcRswfHfS65OZY  GOOGLE
#   10  ChIJLz9srtKHa4cRpb5P3-Zlv1o  GOOGLE
#   11  ChIJMcZKaoeIa4cRGrzf3PhCWAI  GOOGLE
#   12  ChIJf3HGNjeIa4cREW0q_ru-2VA  GOOGLE
#   13  ChIJTe9c3NN3bIcRJ8nYxMPb1kE  GOOGLE
#   14  ChIJ1_VX88aJa4cRyrXhCxpFUDM  GOOGLE
#   15  ChIJc9QSuweJa4cRUogJjHaMJgY  GOOGLE
#   16  ChIJb7ox_sCJa4cRkKXCyVxIlvI  GOOGLE
#   17  ChIJNSV6Ss14bIcRLQDrh0B_isI  GOOGLE
#   18  ChIJJwXpIz-Ia4cRsQPJd_w4o0U  GOOGLE
#   19  ChIJK2RLebmJa4cRVV33IAdmHNo  GOOGLE
#
#                                                   types  user_ratings_total  \
#   0   [bar, restaurant, food, point_of_interest, est...                1157
#   1   [bar, restaurant, food, point_of_interest, est...                2821
#   2   [bar, restaurant, food, point_of_interest, est...                1920
#   3   [meal_takeaway, restaurant, food, point_of_int...                1267
#   4   [meal_takeaway, bar, restaurant, food, point_o...                2092
#   5   [meal_takeaway, bar, restaurant, food, point_o...                 649
#   6   [bar, restaurant, food, point_of_interest, est...                1018
#   7   [restaurant, food, point_of_interest, establis...                1330
#   8   [restaurant, food, point_of_interest, establis...                1202
#   9   [meal_takeaway, restaurant, food, point_of_int...                 104
#   10  [bakery, cafe, restaurant, food, point_of_inte...                 189
#   11  [meal_takeaway, restaurant, food, point_of_int...                  91
#   12  [restaurant, food, point_of_interest, establis...                1724
#   13  [meal_delivery, restaurant, food, point_of_int...                 161
#   14  [meal_takeaway, restaurant, food, point_of_int...                  80
#   15  [meal_takeaway, restaurant, food, point_of_int...                  84
#   16  [bakery, cafe, restaurant, food, point_of_inte...                 353
#   17  [bar, night_club, restaurant, food, point_of_i...                1289
#   18  [restaurant, food, point_of_interest, establis...                1147
#   19  [bowling_alley, bar, restaurant, food, point_o...                 602
#
#                                        vicinity
#   0           8911 N, Yates Street, Westminster
#   1                   5515 Vance Street, Arvada
#   2                   7803 Ralston Road, Arvada
#   3              8971 Yates Street, Westminster
#   4          5551 West 88th Avenue, Westminster
#   5               8350 West 80th Avenue, Arvada
#   6       8711 Wadsworth Boulevard, Westminster
#   7        8665 Sheridan Boulevard, Westminster
#   8      8931 North Yates Drive St, Westminster
#   9         7312 Federal Boulevard, Westminster
#   10       5545 Wadsworth Bypass unit b, Arvada
#   11           6406 Wadsworth Boulevard, Arvada
#   12      4991 West 80th Avenue #b, Westminster
#   13        8410 Federal Boulevard, Westminster
#   14         5076 West 92nd Avenue, Westminster
#   15  8700 Wadsworth Boulevard Unit # A, Arvada
#   16       9392 Sheridan Boulevard, Westminster
#   17        9110 Wadsworth Parkway, Westminster
#   18            7570 Sheridan Boulevard, Arvada
#   19      9150 North Harlan Street, Westminster  },
#  2: {2:                                              geometry  \
#   0   {'location': {'lat': 39.7966522, 'lng': -105.0...
#   1   {'location': {'lat': 39.802305, 'lng': -105.08...
#   2   {'location': {'lat': 39.8411646, 'lng': -105.0...
#   3   {'location': {'lat': 39.7970106, 'lng': -105.0...
#   4   {'location': {'lat': 39.853862, 'lng': -105.08...
#   5   {'location': {'lat': 39.8132251, 'lng': -105.0...
#   6   {'location': {'lat': 39.7907862, 'lng': -105.0...
#   7   {'location': {'lat': 39.8004311, 'lng': -105.1...
#   8   {'location': {'lat': 39.79078620000001, 'lng':...
#   9   {'location': {'lat': 39.79076939999999, 'lng':...
#   10  {'location': {'lat': 39.79998729999999, 'lng':...
#   11  {'location': {'lat': 39.796527, 'lng': -105.07...
#   12  {'location': {'lat': 39.800495, 'lng': -105.08...
#   13  {'location': {'lat': 39.8546355, 'lng': -105.0...
#   14  {'location': {'lat': 39.7931077, 'lng': -105.0...
#   15  {'location': {'lat': 39.8173461, 'lng': -105.0...
#   16  {'location': {'lat': 39.7870129, 'lng': -105.1...
#   17  {'location': {'lat': 39.8334473, 'lng': -105.0...
#   18  {'location': {'lat': 39.83782799999999, 'lng':...
#   19  {'location': {'lat': 39.7928294, 'lng': -105.0...
#
#                                                    icon  \
#   0   https://maps.gstatic.com/mapfiles/place_api/ic...
#   1   https://maps.gstatic.com/mapfiles/place_api/ic...
#   2   https://maps.gstatic.com/mapfiles/place_api/ic...
#   3   https://maps.gstatic.com/mapfiles/place_api/ic...
#   4   https://maps.gstatic.com/mapfiles/place_api/ic...
#   5   https://maps.gstatic.com/mapfiles/place_api/ic...
#   6   https://maps.gstatic.com/mapfiles/place_api/ic...
#   7   https://maps.gstatic.com/mapfiles/place_api/ic...
#   8   https://maps.gstatic.com/mapfiles/place_api/ic...
#   9   https://maps.gstatic.com/mapfiles/place_api/ic...
#   10  https://maps.gstatic.com/mapfiles/place_api/ic...
#   11  https://maps.gstatic.com/mapfiles/place_api/ic...
#   12  https://maps.gstatic.com/mapfiles/place_api/ic...
#   13  https://maps.gstatic.com/mapfiles/place_api/ic...
#   14  https://maps.gstatic.com/mapfiles/place_api/ic...
#   15  https://maps.gstatic.com/mapfiles/place_api/ic...
#   16  https://maps.gstatic.com/mapfiles/place_api/ic...
#   17  https://maps.gstatic.com/mapfiles/place_api/ic...
#   18  https://maps.gstatic.com/mapfiles/place_api/ic...
#   19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                             id  \
#   0   82d6aaf7ec44f97a69d2de5ffd6099ac78e8bbb5
#   1   68651d4197215af836551214cf68ef67811b3635
#   2   811a3299735f555e90346bc1f29a77574c6074f6
#   3   fdaef789275a246d4a8c9e2af7694c2143ef86b8
#   4   8953905d4dacea074199a0f342400d3afed5eab3
#   5   a4f7dc11e1f33fec6448a3b3303e99b916513c6f
#   6   258981772f97e6a6d86282071791b651f42b2350
#   7   dd7e54cb6aecdec0bef21cc2ecb5ec9576df8859
#   8   133cc0826d47a727e347afc68d815ff0b02b5a19
#   9   6afde07953865011a0447f423b15bc5677275472
#   10  8aef009b5799bbcead93d7889b308a5c93d9295c
#   11  b56fffc6698232d52275c995482ac574a5719625
#   12  36bb4800322b43b46ef8dc8d8e7702f6568734d4
#   13  6f006dd7375b3dbe2e0df1822f119bcb999177dd
#   14  13ac5c74544781235d64013f17702b87a0d569b4
#   15  555a6bcb632cb35022a997ab2f5455a1cad42ecb
#   16  8dc348e1b77eadddf5d5c677e333e31b7abe01b7
#   17  4e9f336fd69267ff7e8bb920111553006c74e035
#   18  2acb032d494b8beeb761636a9c12c679db5ea790
#   19  8de016fdb3be8c54ca47868ac358171a9ff33930
#
#                                      name        opening_hours  \
#   0                       Texas Roadhouse   {'open_now': True}
#   1   Yak and Yeti Restaurant and Brewpub   {'open_now': True}
#   2                    Buffalo Wild Wings   {'open_now': True}
#   3                 Einstein Bros. Bagels  {'open_now': False}
#   4                           Old Chicago   {'open_now': True}
#   5                                Subway   {'open_now': True}
#   6                                Subway   {'open_now': True}
#   7                                Subway   {'open_now': True}
#   8          Namiko's Japanese Restaurant   {'open_now': True}
#   9   Red Robin Gourmet Burgers and Brews   {'open_now': True}
#   10        Santiago's Mexican Restaurant   {'open_now': True}
#   11                         Ruby Tuesday   {'open_now': True}
#   12                    The Arvada Tavern   {'open_now': True}
#   13                               Subway   {'open_now': True}
#   14                     Beau Jo's Arvada   {'open_now': True}
#   15             Golden Europe Restaurant   {'open_now': True}
#   16                Luke's, A Steak Place   {'open_now': True}
#   17                   DAE GEE KOREAN BBQ   {'open_now': True}
#   18          Sweet Bloom Coffee Roasters   {'open_now': True}
#   19                                 IHOP   {'open_now': True}
#
#                                                  photos  \
#   0   [{'height': 270, 'html_attributions': ['<a hre...
#   1   [{'height': 608, 'html_attributions': ['<a hre...
#   2   [{'height': 650, 'html_attributions': ['<a hre...
#   3   [{'height': 289, 'html_attributions': ['<a hre...
#   4   [{'height': 3120, 'html_attributions': ['<a hr...
#   5   [{'height': 720, 'html_attributions': ['<a hre...
#   6                                                 NaN
#   7   [{'height': 2340, 'html_attributions': ['<a hr...
#   8   [{'height': 389, 'html_attributions': ['<a hre...
#   9   [{'height': 608, 'html_attributions': ['<a hre...
#   10  [{'height': 1080, 'html_attributions': ['<a hr...
#   11  [{'height': 1960, 'html_attributions': ['<a hr...
#   12  [{'height': 1280, 'html_attributions': ['<a hr...
#   13  [{'height': 2560, 'html_attributions': ['<a hr...
#   14  [{'height': 400, 'html_attributions': ['<a hre...
#   15  [{'height': 2988, 'html_attributions': ['<a hr...
#   16  [{'height': 2269, 'html_attributions': ['<a hr...
#   17  [{'height': 1227, 'html_attributions': ['<a hr...
#   18  [{'height': 1702, 'html_attributions': ['<a hr...
#   19  [{'height': 280, 'html_attributions': ['<a hre...
#
#                          place_id  \
#   0   ChIJt_BPVC2Ga4cRgXscsUD_N_U
#   1   ChIJIZOu6SuGa4cRh4xAPHPxHZ0
#   2   ChIJ02ehs_yIa4cRdOZTKNcaGBE
#   3   ChIJLz9srtKHa4cRpb5P3-Zlv1o
#   4   ChIJi20q_waJa4cRF8lgIqUAeyU
#   5   ChIJMcZKaoeIa4cRGrzf3PhCWAI
#   6   ChIJ3yeALsuHa4cRjyFsuoDaHMU
#   7   ChIJbSePlh-Ga4cR1IYTM3T2fN8
#   8   ChIJ3yeALsuHa4cRb_DIs5mwsNE
#   9   ChIJ4VacTcuHa4cRc_BFCN4L-Fk
#   10  ChIJtTswEx-Ga4cRZvZlx7QSXLQ
#   11  ChIJR3gRWM2Ha4cR5XVwyVp-o1s
#   12  ChIJ97TdiCyGa4cRbL0dR-b7ogo
#   13  ChIJc9QSuweJa4cRUogJjHaMJgY
#   14  ChIJAexs4PiIa4cRYHRp5qqymJQ
#   15  ChIJHfk_bIiIa4cR91HqVO4w7zY
#   16  ChIJBSfh8BOGa4cRtJMQTxIBJog
#   17  ChIJJwXpIz-Ia4cRsQPJd_w4o0U
#   18  ChIJTbDZufmIa4cRiXUi6aof83Y
#   19  ChIJ0XURZDOGa4cRVrcmePRYmvY
#
#                                               plus_code  price_level  rating  \
#   0   {'compound_code': 'QWWC+M4 Arvada, Colorado, U...            2     4.4
#   1   {'compound_code': 'RW28+W8 Arvada, Colorado, U...            2     4.6
#   2   {'compound_code': 'RWR5+FQ Arvada, Colorado, U...            2     3.4
#   3   {'compound_code': 'QWWC+RG Arvada, Colorado, U...            1     3.7
#   4   {'compound_code': 'VW39+G3 Westminster, Colora...            2     4.0
#   5   {'compound_code': 'RW7C+78 Arvada, Colorado, U...            1     4.2
#   6   {'compound_code': 'QWRC+8Q Arvada, Colorado, U...            1     3.5
#   7   {'compound_code': 'RV2W+5W Arvada, Colorado, U...            1     3.4
#   8   {'compound_code': 'QWRC+8V Arvada, Colorado, U...            2     4.5
#   9   {'compound_code': 'QWRC+8F Arvada, Colorado, U...            2     3.9
#   10  {'compound_code': 'QVXW+XC Arvada, Colorado, U...            1     4.1
#   11  {'compound_code': 'QWWC+JQ Arvada, Colorado, U...            2     3.7
#   12  {'compound_code': 'RW29+59 Arvada, Colorado, U...            2     4.6
#   13  {'compound_code': 'VW39+VG Arvada, Colorado, U...            1     3.3
#   14  {'compound_code': 'QWVC+6F Arvada, Colorado, U...            2     4.3
#   15  {'compound_code': 'RW89+WJ Arvada, Colorado, U...            2     4.7
#   16  {'compound_code': 'QVPR+RH Wheat Ridge, Colora...            2     4.3
#   17  {'compound_code': 'RWMX+92 Arvada, Colorado, U...            2     4.4
#   18  {'compound_code': 'RWQ8+4J Arvada, Colorado, U...            2     4.7
#   19  {'compound_code': 'QWVC+44 Arvada, Colorado, U...            1     3.8
#
#                         reference   scope  \
#   0   ChIJt_BPVC2Ga4cRgXscsUD_N_U  GOOGLE
#   1   ChIJIZOu6SuGa4cRh4xAPHPxHZ0  GOOGLE
#   2   ChIJ02ehs_yIa4cRdOZTKNcaGBE  GOOGLE
#   3   ChIJLz9srtKHa4cRpb5P3-Zlv1o  GOOGLE
#   4   ChIJi20q_waJa4cRF8lgIqUAeyU  GOOGLE
#   5   ChIJMcZKaoeIa4cRGrzf3PhCWAI  GOOGLE
#   6   ChIJ3yeALsuHa4cRjyFsuoDaHMU  GOOGLE
#   7   ChIJbSePlh-Ga4cR1IYTM3T2fN8  GOOGLE
#   8   ChIJ3yeALsuHa4cRb_DIs5mwsNE  GOOGLE
#   9   ChIJ4VacTcuHa4cRc_BFCN4L-Fk  GOOGLE
#   10  ChIJtTswEx-Ga4cRZvZlx7QSXLQ  GOOGLE
#   11  ChIJR3gRWM2Ha4cR5XVwyVp-o1s  GOOGLE
#   12  ChIJ97TdiCyGa4cRbL0dR-b7ogo  GOOGLE
#   13  ChIJc9QSuweJa4cRUogJjHaMJgY  GOOGLE
#   14  ChIJAexs4PiIa4cRYHRp5qqymJQ  GOOGLE
#   15  ChIJHfk_bIiIa4cR91HqVO4w7zY  GOOGLE
#   16  ChIJBSfh8BOGa4cRtJMQTxIBJog  GOOGLE
#   17  ChIJJwXpIz-Ia4cRsQPJd_w4o0U  GOOGLE
#   18  ChIJTbDZufmIa4cRiXUi6aof83Y  GOOGLE
#   19  ChIJ0XURZDOGa4cRVrcmePRYmvY  GOOGLE
#
#                                                   types  user_ratings_total  \
#   0   [bar, restaurant, food, point_of_interest, est...                2821
#   1   [bar, restaurant, food, point_of_interest, est...                1920
#   2   [meal_takeaway, bar, restaurant, food, point_o...                 649
#   3   [bakery, cafe, restaurant, food, point_of_inte...                 189
#   4   [bar, restaurant, food, point_of_interest, est...                1018
#   5   [meal_takeaway, restaurant, food, point_of_int...                  91
#   6   [meal_takeaway, restaurant, food, point_of_int...                  87
#   7   [meal_takeaway, restaurant, food, point_of_int...                  25
#   8   [restaurant, food, point_of_interest, establis...                 422
#   9   [restaurant, food, point_of_interest, establis...                1106
#   10  [restaurant, food, point_of_interest, establis...                 995
#   11  [bar, restaurant, food, point_of_interest, est...                 963
#   12  [night_club, bar, restaurant, food, point_of_i...                 887
#   13  [meal_takeaway, restaurant, food, point_of_int...                  84
#   14  [bar, restaurant, food, point_of_interest, est...                1855
#   15  [restaurant, food, point_of_interest, establis...                 446
#   16  [restaurant, food, point_of_interest, establis...                 296
#   17  [restaurant, food, point_of_interest, establis...                1147
#   18  [bakery, cafe, restaurant, food, point_of_inte...                 593
#   19  [restaurant, food, point_of_interest, establis...                 695
#
#                                        vicinity
#   0                   5515 Vance Street, Arvada
#   1                   7803 Ralston Road, Arvada
#   2               8350 West 80th Avenue, Arvada
#   3        5545 Wadsworth Bypass unit b, Arvada
#   4       8711 Wadsworth Boulevard, Westminster
#   5            6406 Wadsworth Boulevard, Arvada
#   6            7310 West 52nd Avenue #C, Arvada
#   7                   9400 Ralston Road, Arvada
#   8        7310 West 52nd Avenue unit R, Arvada
#   9               7460 West 52nd Avenue, Arvada
#   10              9575 West 57th Avenue, Arvada
#   11              5525 Wadsworth Bypass, Arvada
#   12      5707 Olde Wadsworth Boulevard, Arvada
#   13  8700 Wadsworth Boulevard Unit # A, Arvada
#   14              7525 West 53rd Avenue, Arvada
#   15           6620 Wadsworth Boulevard, Arvada
#   16        4990 Kipling Street #1, Wheat Ridge
#   17            7570 Sheridan Boulevard, Arvada
#   18         7745 Wadsworth Boulevard C, Arvada
#   19              5280 Wadsworth Bypass, Arvada  },
#  3: {3:                                              geometry  \
#   0   {'location': {'lat': 39.8411646, 'lng': -105.0...
#   1   {'location': {'lat': 39.853862, 'lng': -105.08...
#   2   {'location': {'lat': 39.8496213, 'lng': -105.1...
#   3   {'location': {'lat': 39.877009, 'lng': -105.09...
#   4   {'location': {'lat': 39.8546355, 'lng': -105.0...
#   5   {'location': {'lat': 39.86141629999999, 'lng':...
#   6   {'location': {'lat': 39.8591216, 'lng': -105.0...
#   7   {'location': {'lat': 39.868128, 'lng': -105.08...
#   8   {'location': {'lat': 39.8561261, 'lng': -105.0...
#   9   {'location': {'lat': 39.83782799999999, 'lng':...
#   10  {'location': {'lat': 39.83921470000001, 'lng':...
#   11  {'location': {'lat': 39.856862, 'lng': -105.08...
#   12  {'location': {'lat': 39.854097, 'lng': -105.08...
#   13  {'location': {'lat': 39.8540573, 'lng': -105.0...
#   14  {'location': {'lat': 39.8641745, 'lng': -105.0...
#   15  {'location': {'lat': 39.85971550000001, 'lng':...
#   16  {'location': {'lat': 39.811387, 'lng': -105.13...
#   17  {'location': {'lat': 39.8552997, 'lng': -105.0...
#   18  {'location': {'lat': 39.8585346, 'lng': -105.0...
#   19  {'location': {'lat': 39.877601, 'lng': -105.09...
#
#                                                    icon  \
#   0   https://maps.gstatic.com/mapfiles/place_api/ic...
#   1   https://maps.gstatic.com/mapfiles/place_api/ic...
#   2   https://maps.gstatic.com/mapfiles/place_api/ic...
#   3   https://maps.gstatic.com/mapfiles/place_api/ic...
#   4   https://maps.gstatic.com/mapfiles/place_api/ic...
#   5   https://maps.gstatic.com/mapfiles/place_api/ic...
#   6   https://maps.gstatic.com/mapfiles/place_api/ic...
#   7   https://maps.gstatic.com/mapfiles/place_api/ic...
#   8   https://maps.gstatic.com/mapfiles/place_api/ic...
#   9   https://maps.gstatic.com/mapfiles/place_api/ic...
#   10  https://maps.gstatic.com/mapfiles/place_api/ic...
#   11  https://maps.gstatic.com/mapfiles/place_api/ic...
#   12  https://maps.gstatic.com/mapfiles/place_api/ic...
#   13  https://maps.gstatic.com/mapfiles/place_api/ic...
#   14  https://maps.gstatic.com/mapfiles/place_api/ic...
#   15  https://maps.gstatic.com/mapfiles/place_api/ic...
#   16  https://maps.gstatic.com/mapfiles/place_api/ic...
#   17  https://maps.gstatic.com/mapfiles/place_api/ic...
#   18  https://maps.gstatic.com/mapfiles/place_api/ic...
#   19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                             id  \
#   0   811a3299735f555e90346bc1f29a77574c6074f6
#   1   8953905d4dacea074199a0f342400d3afed5eab3
#   2   f0ca6358f34269307e56b23f088e3675af7bf704
#   3   5510cfb541b5aa59173ab49f7c2b36c8ef47c47d
#   4   6f006dd7375b3dbe2e0df1822f119bcb999177dd
#   5   88f762c08d444b66d1472bb4b86c886ff0405b76
#   6   15b16a4aafa3ba772f7d3058580f651740317695
#   7   ca5c1b1932aa6174668157d9fefecc2bece77a30
#   8   0396dcf9b10aa82af965310c956e8f1fe7d129db
#   9   2acb032d494b8beeb761636a9c12c679db5ea790
#   10  ba8a5cb6fed0d72b48487c19af9ddfd3553aa2ce
#   11  cdd2cff6ad036362cc9c4f23985571fee58c9fae
#   12  885e4c6c9f240426d0320f764dffb80613daae80
#   13  ca57ee0d1a8b358e4c24e72a90e0336cfe1d8d91
#   14  65168779d290c87b6e37944e642f6c5af69dc78a
#   15  1bd1c091f855d3426c0794c11a29e21baac61cc7
#   16  f86afdf803f2d2f3822710cdfc6eeded1a9f200b
#   17  88319a906be2f50cb19f66459c6b64c3b66b3825
#   18  836b871f87601920a70e645378bb7b2e0f5b20f5
#   19  5db00691989b346bbc012422b96c4fc3ee22c229
#
#                                            name        opening_hours  \
#   0                          Buffalo Wild Wings   {'open_now': True}
#   1                                 Old Chicago   {'open_now': True}
#   2                         Jack’s and Steamers   {'open_now': True}
#   3                   LaMar's Donuts and Coffee   {'open_now': True}
#   4                                      Subway   {'open_now': True}
#   5                                    Hoffbrau   {'open_now': True}
#   6                 The Honey Baked Ham Company   {'open_now': True}
#   7   Cracovia Polish-American Restaurant & Bar   {'open_now': True}
#   8                      Chipotle Mexican Grill   {'open_now': True}
#   9                 Sweet Bloom Coffee Roasters   {'open_now': True}
#   10                                Chick-fil-A   {'open_now': True}
#   11                        Chili's Grill & Bar   {'open_now': True}
#   12     Santeramo's Pizza & Italian Restaurant   {'open_now': True}
#   13                               Jimmy John's   {'open_now': True}
#   14                   Carrabba's Italian Grill   {'open_now': True}
#   15                     Applebee's Grill + Bar   {'open_now': True}
#   16                     Chipotle Mexican Grill   {'open_now': True}
#   17                       Little Caesars Pizza   {'open_now': True}
#   18                  Le Peep® 88th & Wadsworth  {'open_now': False}
#   19                          G's Tacos - Westy   {'open_now': True}
#
#                                                  photos  \
#   0   [{'height': 650, 'html_attributions': ['<a hre...
#   1   [{'height': 3120, 'html_attributions': ['<a hr...
#   2   [{'height': 1836, 'html_attributions': ['<a hr...
#   3   [{'height': 289, 'html_attributions': ['<a hre...
#   4   [{'height': 2560, 'html_attributions': ['<a hr...
#   5   [{'height': 1836, 'html_attributions': ['<a hr...
#   6   [{'height': 749, 'html_attributions': ['<a hre...
#   7   [{'height': 750, 'html_attributions': ['<a hre...
#   8   [{'height': 3024, 'html_attributions': ['<a hr...
#   9   [{'height': 1702, 'html_attributions': ['<a hr...
#   10  [{'height': 288, 'html_attributions': ['<a hre...
#   11  [{'height': 3024, 'html_attributions': ['<a hr...
#   12  [{'height': 333, 'html_attributions': ['<a hre...
#   13  [{'height': 2988, 'html_attributions': ['<a hr...
#   14  [{'height': 728, 'html_attributions': ['<a hre...
#   15  [{'height': 4160, 'html_attributions': ['<a hr...
#   16  [{'height': 4032, 'html_attributions': ['<a hr...
#   17  [{'height': 1920, 'html_attributions': ['<a hr...
#   18  [{'height': 2848, 'html_attributions': ['<a hr...
#   19  [{'height': 700, 'html_attributions': ['<a hre...
#
#                          place_id  \
#   0   ChIJ02ehs_yIa4cRdOZTKNcaGBE
#   1   ChIJi20q_waJa4cRF8lgIqUAeyU
#   2   ChIJZwfa2e6Oa4cROw9h3WU8o8w
#   3   ChIJ_bpRr2WJa4cRgYnxSUW8bt0
#   4   ChIJc9QSuweJa4cRUogJjHaMJgY
#   5   ChIJNSV6Ss14bIcRLQDrh0B_isI
#   6   ChIJ7Qxd1geJa4cRK9xO1cd4EDA
#   7   ChIJmeBX8HKJa4cRt610aSfCZAY
#   8   ChIJzfOSzQeJa4cRjmhGH05kkzM
#   9   ChIJTbDZufmIa4cRiXUi6aof83Y
#   10  ChIJF8N4HvmIa4cRr6U3DvhBREM
#   11  ChIJpTl2FAiJa4cRPcuXMO88GjY
#   12  ChIJnyNUCAeJa4cR7TviRy3Um3Q
#   13  ChIJN_kdBgeJa4cRJ67-95usDT8
#   14  ChIJZz1KXwqJa4cRR56V5oyoN98
#   15  ChIJ_cZnsAmJa4cRjuCjuuJV9aU
#   16  ChIJJ5Ysx0WPa4cRxucg3X8uXaw
#   17  ChIJpUpl6weJa4cR2kUm-Xbkdo4
#   18  ChIJBeP3RgiJa4cRGMFxoF8sFlU
#   19  ChIJFTHK_WaJa4cRj2dWhe1scx8
#
#                                               plus_code  price_level  rating  \
#   0   {'compound_code': 'RWR5+FQ Arvada, Colorado, U...            2     3.4
#   1   {'compound_code': 'VW39+G3 Westminster, Colora...            2     4.0
#   2   {'compound_code': 'RRXV+RP Arvada, Colorado, U...            2     4.4
#   3   {'compound_code': 'VWG4+RC Westminster, Colora...            1     4.5
#   4   {'compound_code': 'VW39+VG Arvada, Colorado, U...            1     3.3
#   5   {'compound_code': 'VW6C+H2 Westminster, Colora...            2     4.2
#   6   {'compound_code': 'VW59+JJ Westminster, Colora...            2     4.5
#   7   {'compound_code': 'VW96+7G Westminster, Colora...            2     4.5
#   8   {'compound_code': 'VW49+F2 Arvada, Colorado, U...            1     4.2
#   9   {'compound_code': 'RWQ8+4J Arvada, Colorado, U...            2     4.7
#   10  {'compound_code': 'RWQ9+M3 Arvada, Colorado, U...            1     4.4
#   11  {'compound_code': 'VW49+PW Westminster, Colora...            2     4.0
#   12  {'compound_code': 'VW39+JC Arvada, Colorado, U...            2     4.1
#   13  {'compound_code': 'VW39+JH Arvada, Colorado, U...            1     3.8
#   14  {'compound_code': 'VW79+MG Westminster, Colora...            2     4.3
#   15  {'compound_code': 'VW59+VH Westminster, Colora...            2     3.9
#   16  {'compound_code': 'RV66+H4 Arvada, Colorado, U...            1     3.9
#   17  {'compound_code': 'VW49+4V Arvada, Colorado, U...            1     3.8
#   18  {'compound_code': 'VW59+CP Westminster, Colora...            2     4.2
#   19  {'compound_code': 'VWH2+29 Broomfield, Colorad...            1     4.4
#
#                         reference   scope  \
#   0   ChIJ02ehs_yIa4cRdOZTKNcaGBE  GOOGLE
#   1   ChIJi20q_waJa4cRF8lgIqUAeyU  GOOGLE
#   2   ChIJZwfa2e6Oa4cROw9h3WU8o8w  GOOGLE
#   3   ChIJ_bpRr2WJa4cRgYnxSUW8bt0  GOOGLE
#   4   ChIJc9QSuweJa4cRUogJjHaMJgY  GOOGLE
#   5   ChIJNSV6Ss14bIcRLQDrh0B_isI  GOOGLE
#   6   ChIJ7Qxd1geJa4cRK9xO1cd4EDA  GOOGLE
#   7   ChIJmeBX8HKJa4cRt610aSfCZAY  GOOGLE
#   8   ChIJzfOSzQeJa4cRjmhGH05kkzM  GOOGLE
#   9   ChIJTbDZufmIa4cRiXUi6aof83Y  GOOGLE
#   10  ChIJF8N4HvmIa4cRr6U3DvhBREM  GOOGLE
#   11  ChIJpTl2FAiJa4cRPcuXMO88GjY  GOOGLE
#   12  ChIJnyNUCAeJa4cR7TviRy3Um3Q  GOOGLE
#   13  ChIJN_kdBgeJa4cRJ67-95usDT8  GOOGLE
#   14  ChIJZz1KXwqJa4cRR56V5oyoN98  GOOGLE
#   15  ChIJ_cZnsAmJa4cRjuCjuuJV9aU  GOOGLE
#   16  ChIJJ5Ysx0WPa4cRxucg3X8uXaw  GOOGLE
#   17  ChIJpUpl6weJa4cR2kUm-Xbkdo4  GOOGLE
#   18  ChIJBeP3RgiJa4cRGMFxoF8sFlU  GOOGLE
#   19  ChIJFTHK_WaJa4cRj2dWhe1scx8  GOOGLE
#
#                                                   types  user_ratings_total  \
#   0   [meal_takeaway, bar, restaurant, food, point_o...                 649
#   1   [bar, restaurant, food, point_of_interest, est...                1018
#   2   [cafe, bar, restaurant, food, point_of_interes...                 578
#   3   [bakery, cafe, restaurant, food, point_of_inte...                 620
#   4   [meal_takeaway, restaurant, food, point_of_int...                  84
#   5   [bar, night_club, restaurant, food, point_of_i...                1289
#   6   [meal_takeaway, cafe, restaurant, food, point_...                 164
#   7   [bar, restaurant, food, point_of_interest, est...                 534
#   8   [restaurant, food, point_of_interest, establis...                 671
#   9   [bakery, cafe, restaurant, food, point_of_inte...                 593
#   10  [restaurant, food, point_of_interest, establis...                 877
#   11  [bar, restaurant, food, point_of_interest, est...                 943
#   12  [meal_delivery, restaurant, food, point_of_int...                 270
#   13  [meal_delivery, restaurant, food, point_of_int...                  69
#   14  [restaurant, food, point_of_interest, establis...                 959
#   15  [restaurant, bar, food, point_of_interest, est...                 704
# ...
#   2  https://maps.gstatic.com/mapfiles/place_api/ic...
#   3  https://maps.gstatic.com/mapfiles/place_api/ic...
#   4  https://maps.gstatic.com/mapfiles/place_api/ic...
#   5  https://maps.gstatic.com/mapfiles/place_api/ic...
#   6  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                            id                        name  \
#   0  64f6f160c680214458a279cdd607720a3a2526d7                    The Fort
#   1  b07573ef67c529d87665f5d44aca4d469f373930  Yampa Valley Sauce Company
#   2  695560189e01e3eeb5b7830ba42b7c289c3c05f7           The Cow An Eatery
#   3  82688e6585136c3d533b5544a59a536fa3ae06a0           Sit N Bull Saloon
#   4  d0d746ab0567d81a198eb286b48038c1a69e84ae           Twin Forks Tavern
#   5  573f64a7ed5de1cadcf1b7da5ea9e1d4f18eaafe                    The Fort
#   6  13cbccb00cc5ea867f709042a641762fe95cadf4            Tap On The Rocks
#
#            opening_hours                                             photos  \
#   0   {'open_now': True}  [{'height': 1152, 'html_attributions': ['<a hr...
#   1                  NaN                                                NaN
#   2   {'open_now': True}  [{'height': 2988, 'html_attributions': ['<a hr...
#   3   {'open_now': True}  [{'height': 1152, 'html_attributions': ['<a hr...
#   4   {'open_now': True}  [{'height': 2988, 'html_attributions': ['<a hr...
#   5   {'open_now': True}  [{'height': 478, 'html_attributions': ['<a hre...
#   6  {'open_now': False}  [{'height': 4032, 'html_attributions': ['<a hr...
#
#                         place_id  \
#   0  ChIJU2JjmHV4a4cR1aHNt9R9QQQ
#   1  ChIJMU_MMVyda4cRlmUKwcG-r70
#   2  ChIJ0es7mOuCa4cRswxgxeOkVDw
#   3  ChIJkw7hR-F3a4cRUG3UtWHiIT0
#   4  ChIJ1xAzOYd3a4cRbNULfLiM2Zc
#   5  ChIJf61vrz55a4cRJ-YGyPP17lA
#   6  ChIJGZF9ueuCa4cR-sdEDHh-_g0
#
#                                              plus_code  price_level  rating  \
#   0  {'compound_code': 'JRH5+H2 Morrison, Colorado,...          4.0     4.4
#   1  {'compound_code': 'JQH6+V6 Indian Hills, Color...          NaN     5.0
#   2  {'compound_code': 'MR35+F9 Morrison, Colorado,...          2.0     4.4
#   3  {'compound_code': 'JQ97+F3 Indian Hills, Color...          1.0     4.4
#   4  {'compound_code': 'HQRH+RG Homestead, Colorado...          2.0     4.6
#   5  {'compound_code': 'JRH5+G2 Morrison, Colorado,...          NaN     4.5
#   6  {'compound_code': 'MR35+H6 Morrison, Colorado,...          1.0     4.0
#
#                        reference   scope  \
#   0  ChIJU2JjmHV4a4cR1aHNt9R9QQQ  GOOGLE
#   1  ChIJMU_MMVyda4cRlmUKwcG-r70  GOOGLE
#   2  ChIJ0es7mOuCa4cRswxgxeOkVDw  GOOGLE
#   3  ChIJkw7hR-F3a4cRUG3UtWHiIT0  GOOGLE
#   4  ChIJ1xAzOYd3a4cRbNULfLiM2Zc  GOOGLE
#   5  ChIJf61vrz55a4cRJ-YGyPP17lA  GOOGLE
#   6  ChIJGZF9ueuCa4cR-sdEDHh-_g0  GOOGLE
#
#                                                  types  user_ratings_total  \
#   0  [bar, restaurant, food, point_of_interest, est...                1341
#   1  [restaurant, food, point_of_interest, establis...                   2
#   2  [cafe, restaurant, food, point_of_interest, st...                1288
#   3  [bar, restaurant, food, point_of_interest, est...                 368
#   4  [bar, restaurant, food, point_of_interest, est...                 262
#   5  [restaurant, food, point_of_interest, establis...                 105
#   6  [restaurant, food, point_of_interest, establis...                 340
#
#                                      vicinity
#   0                19192 Colorado 8, Morrison
#   1                                  Morrison
#   2           316 Bear Creek Avenue, Morrison
#   3  5450 S Parmalee Gulch Road, Indian Hills
#   4   19423 North Turkey Creek Road, Morrison
#   5                19192 Colorado 8, Morrison
#   6           408 Bear Creek Avenue, Morrison  },
#  24: {24:                                              geometry  \
#   0   {'location': {'lat': 39.628917, 'lng': -105.19...
#   1   {'location': {'lat': 39.6539362, 'lng': -105.1...
#   2   {'location': {'lat': 39.6537352, 'lng': -105.1...
#   3   {'location': {'lat': 39.65373019999999, 'lng':...
#   4   {'location': {'lat': 39.68227220000001, 'lng':...
#   5   {'location': {'lat': 39.66685639999999, 'lng':...
#   6   {'location': {'lat': 39.6538041, 'lng': -105.1...
#   7   {'location': {'lat': 39.635394, 'lng': -105.15...
#   8   {'location': {'lat': 39.654347, 'lng': -105.19...
#   9   {'location': {'lat': 39.653249, 'lng': -105.18...
#   10  {'location': {'lat': 39.6534151, 'lng': -105.1...
#   11  {'location': {'lat': 39.65387550000001, 'lng':...
#   12  {'location': {'lat': 39.6652511, 'lng': -105.2...
#   13  {'location': {'lat': 39.635423, 'lng': -105.15...
#   14  {'location': {'lat': 39.65415039999999, 'lng':...
#   15  {'location': {'lat': 39.654347, 'lng': -105.19...
#   16  {'location': {'lat': 39.65977609999999, 'lng':...
#   17  {'location': {'lat': 39.6354234, 'lng': -105.1...
#   18  {'location': {'lat': 39.6288251, 'lng': -105.1...
#   19  {'location': {'lat': 39.682657, 'lng': -105.15...
#
#                                                    icon  \
#   0   https://maps.gstatic.com/mapfiles/place_api/ic...
#   1   https://maps.gstatic.com/mapfiles/place_api/ic...
#   2   https://maps.gstatic.com/mapfiles/place_api/ic...
#   3   https://maps.gstatic.com/mapfiles/place_api/ic...
#   4   https://maps.gstatic.com/mapfiles/place_api/ic...
#   5   https://maps.gstatic.com/mapfiles/place_api/ic...
#   6   https://maps.gstatic.com/mapfiles/place_api/ic...
#   7   https://maps.gstatic.com/mapfiles/place_api/ic...
#   8   https://maps.gstatic.com/mapfiles/place_api/ic...
#   9   https://maps.gstatic.com/mapfiles/place_api/ic...
#   10  https://maps.gstatic.com/mapfiles/place_api/ic...
#   11  https://maps.gstatic.com/mapfiles/place_api/ic...
#   12  https://maps.gstatic.com/mapfiles/place_api/ic...
#   13  https://maps.gstatic.com/mapfiles/place_api/ic...
#   14  https://maps.gstatic.com/mapfiles/place_api/ic...
#   15  https://maps.gstatic.com/mapfiles/place_api/ic...
#   16  https://maps.gstatic.com/mapfiles/place_api/ic...
#   17  https://maps.gstatic.com/mapfiles/place_api/ic...
#   18  https://maps.gstatic.com/mapfiles/place_api/ic...
#   19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                             id                             name  \
#   0   64f6f160c680214458a279cdd607720a3a2526d7                         The Fort
#   1   22ce50c69b255fa16ffdaf3ab6915c09cda3084a                     Morrison Inn
#   2   e45b31e3b542da410f13d9ee74e4315ded2e7ff4  Tony Rigatoni's Italian Kitchen
#   3   695560189e01e3eeb5b7830ba42b7c289c3c05f7                The Cow An Eatery
#   4   3dd94fe22d9c0a08ec1bc42eb6d63f166803060c                  Frontroom Pizza
#   5   8deccb0e391b949910fcce1d7aea12fc710a5775                           Subway
#   6   04e62ed88f469de57c15e18d2f758fb647d5e49d                  Roof Top Tavern
#   7   b0b78b51274c5caecb0d3811eb076c02326966f9                         Circle K
#   8   688fbc4c6eccff1be519538d974b0b3e04dadefd                  Red Rocks Grill
#   9   ebdb92d2248eda9f2e39504be251a2614b9dcb7f                    Willy's Wings
#   10  1f1258eae0faf540aba73f423e9df1a1612370ba                     Beso De Arte
#   11  13cbccb00cc5ea867f709042a641762fe95cadf4                 Tap On The Rocks
#   12  aec51552ae64514db47c7f72f3c94ef9efe185d6                 Ship Rock Grille
#   13  0a79e2906bbee5534515236ad34e326f020552fa                     Tommy's Subs
#   14  03b2dadcf31b6e0aee3e37d0ee00afe4ddcdce4c                 Mill Street Eats
#   15  cc0e749e902e58085b6128a6efaf225124a8c5f8            Red Rocks Beer Garden
#   16  d812519014d7eb24b78c04705e855d3e18f0c955                Snowie Shaved Ice
#   17  e8809c26f9c81d6931fda2d8776b0a039cd94424         5281 STEAK SALAD SEAFOOD
#   18  573f64a7ed5de1cadcf1b7da5ea9e1d4f18eaafe                         The Fort
#   19  9b6ce8d7aa90f1d5a50fa2ab410b5379edfb3735                 Abes Bar & Grill
#
#             opening_hours                                             photos  \
#   0    {'open_now': True}  [{'height': 1152, 'html_attributions': ['<a hr...
#   1    {'open_now': True}  [{'height': 1836, 'html_attributions': ['<a hr...
#   2    {'open_now': True}  [{'height': 844, 'html_attributions': ['<a hre...
#   3    {'open_now': True}  [{'height': 2988, 'html_attributions': ['<a hr...
#   4    {'open_now': True}  [{'height': 1200, 'html_attributions': ['<a hr...
#   5    {'open_now': True}  [{'height': 1344, 'html_attributions': ['<a hr...
#   6    {'open_now': True}  [{'height': 844, 'html_attributions': ['<a hre...
#   7    {'open_now': True}  [{'height': 1920, 'html_attributions': ['<a hr...
#   8    {'open_now': True}  [{'height': 3024, 'html_attributions': ['<a hr...
#   9    {'open_now': True}  [{'height': 3120, 'html_attributions': ['<a hr...
#   10   {'open_now': True}  [{'height': 4056, 'html_attributions': ['<a hr...
#   11  {'open_now': False}  [{'height': 4032, 'html_attributions': ['<a hr...
#   12  {'open_now': False}  [{'height': 3024, 'html_attributions': ['<a hr...
#   13   {'open_now': True}  [{'height': 2592, 'html_attributions': ['<a hr...
#   14   {'open_now': True}  [{'height': 4032, 'html_attributions': ['<a hr...
#   15   {'open_now': True}  [{'height': 1049, 'html_attributions': ['<a hr...
#   16  {'open_now': False}  [{'height': 1920, 'html_attributions': ['<a hr...
#   17   {'open_now': True}  [{'height': 4032, 'html_attributions': ['<a hr...
#   18   {'open_now': True}  [{'height': 478, 'html_attributions': ['<a hre...
#   19   {'open_now': True}  [{'height': 1080, 'html_attributions': ['<a hr...
#
#                          place_id  \
#   0   ChIJU2JjmHV4a4cR1aHNt9R9QQQ
#   1   ChIJYdpThOuCa4cRlwkh2G037lA
#   2   ChIJH9kKh-uCa4cRKm1CnovY8cM
#   3   ChIJ0es7mOuCa4cRswxgxeOkVDw
#   4   ChIJ8b1cPLGDa4cR7izRVtshoJY
#   5   ChIJh4V4E0iCa4cR0ZVKeKQA5jw
#   6   ChIJ8eYihOuCa4cRrhnKRX3K04I
#   7   ChIJT4jLLXaCa4cR2_bOBxlq504
#   8   ChIJxTL6vuuCa4cRg-qlq0reN9Y
#   9   ChIJXfCgC-qCa4cRAew59CXWmqY
#   10  ChIJg6JhfeyCa4cRg8PbcE7cPeY
#   11  ChIJGZF9ueuCa4cR-sdEDHh-_g0
#   12  ChIJD4GV6NeCa4cRYMcQADCkf6k
#   13  ChIJT4jLLXaCa4cRrydLfsj4B6M
#   14  ChIJeQFowOuCa4cRyDIx3-KJDwo
#   15  ChIJAQC8deyCa4cRJh_zEHclTeU
#   16  ChIJeaoEa0SDa4cR5T-RctSMUWs
#   17  ChIJT4jLLXaCa4cRrCvSma7grMk
#   18  ChIJf61vrz55a4cRJ-YGyPP17lA
#   19  ChIJ44EFL7GDa4cRTv8Lww93xrQ
#
#                                               plus_code  price_level  rating  \
#   0   {'compound_code': 'JRH5+H2 Morrison, Colorado,...          4.0     4.4
#   1   {'compound_code': 'MR35+HP Morrison, Colorado,...          2.0     4.0
#   2   {'compound_code': 'MR35+FQ Morrison, Colorado,...          2.0     4.1
#   3   {'compound_code': 'MR35+F9 Morrison, Colorado,...          2.0     4.4
#   4   {'compound_code': 'MRJV+WF Denver, Colorado, U...          2.0     4.5
#   5   {'compound_code': 'MR8X+PP Lakewood, Colorado,...          1.0     3.5
#   6   {'compound_code': 'MR35+GQ Morrison, Colorado,...          2.0     4.2
#   7   {'compound_code': 'JRPR+5V Morrison, Colorado,...          1.0     3.0
#   8   {'compound_code': 'MR35+P5 Morrison, Colorado,...          2.0     4.1
#   9   {'compound_code': 'MR36+7C Morrison, Colorado,...          1.0     4.4
#   10  {'compound_code': 'MR36+95 Morrison, Colorado,...          2.0     4.3
#   11  {'compound_code': 'MR35+H6 Morrison, Colorado,...          1.0     4.0
#   12  {'compound_code': 'MQ8V+48 Morrison, Colorado,...          NaN     4.1
#   13  {'compound_code': 'JRPR+5V Morrison, Colorado,...          1.0     4.7
#   14  {'compound_code': 'MR35+M8 Morrison, Colorado,...          NaN     3.4
#   15  {'compound_code': 'MR35+PX Morrison, Colorado,...          NaN     4.8
#   16  {'compound_code': 'MR56+WR Morrison, Colorado,...          NaN     NaN
#   17  {'compound_code': 'JRPR+5V Morrison, Colorado,...          2.0     4.6
#   18  {'compound_code': 'JRH5+G2 Morrison, Colorado,...          NaN     4.5
#   19  {'compound_code': 'MRMV+3V Lakewood, Colorado,...          2.0     4.6
#
#                         reference   scope  \
#   0   ChIJU2JjmHV4a4cR1aHNt9R9QQQ  GOOGLE
#   1   ChIJYdpThOuCa4cRlwkh2G037lA  GOOGLE
#   2   ChIJH9kKh-uCa4cRKm1CnovY8cM  GOOGLE
#   3   ChIJ0es7mOuCa4cRswxgxeOkVDw  GOOGLE
#   4   ChIJ8b1cPLGDa4cR7izRVtshoJY  GOOGLE
#   5   ChIJh4V4E0iCa4cR0ZVKeKQA5jw  GOOGLE
#   6   ChIJ8eYihOuCa4cRrhnKRX3K04I  GOOGLE
#   7   ChIJT4jLLXaCa4cR2_bOBxlq504  GOOGLE
#   8   ChIJxTL6vuuCa4cRg-qlq0reN9Y  GOOGLE
#   9   ChIJXfCgC-qCa4cRAew59CXWmqY  GOOGLE
#   10  ChIJg6JhfeyCa4cRg8PbcE7cPeY  GOOGLE
#   11  ChIJGZF9ueuCa4cR-sdEDHh-_g0  GOOGLE
#   12  ChIJD4GV6NeCa4cRYMcQADCkf6k  GOOGLE
#   13  ChIJT4jLLXaCa4cRrydLfsj4B6M  GOOGLE
#   14  ChIJeQFowOuCa4cRyDIx3-KJDwo  GOOGLE
#   15  ChIJAQC8deyCa4cRJh_zEHclTeU  GOOGLE
#   16  ChIJeaoEa0SDa4cR5T-RctSMUWs  GOOGLE
#   17  ChIJT4jLLXaCa4cRrCvSma7grMk  GOOGLE
#   18  ChIJf61vrz55a4cRJ-YGyPP17lA  GOOGLE
#   19  ChIJ44EFL7GDa4cRTv8Lww93xrQ  GOOGLE
#
#                                                   types  user_ratings_total  \
#   0   [bar, restaurant, food, point_of_interest, est...              1341.0
#   1   [restaurant, food, point_of_interest, establis...              1148.0
#   2   [restaurant, food, point_of_interest, establis...               277.0
#   3   [cafe, restaurant, food, point_of_interest, st...              1288.0
#   4   [restaurant, food, point_of_interest, establis...               680.0
#   5   [meal_takeaway, restaurant, food, point_of_int...                59.0
#   6   [bar, restaurant, food, point_of_interest, est...               267.0
#   7   [convenience_store, gas_station, meal_takeaway...                26.0
#   8   [bar, restaurant, food, point_of_interest, est...               689.0
#   9   [meal_delivery, meal_takeaway, bar, restaurant...               640.0
#   10  [restaurant, food, point_of_interest, establis...               281.0
#   11  [restaurant, food, point_of_interest, establis...               340.0
#   12  [bar, restaurant, food, point_of_interest, est...               163.0
#   13  [restaurant, food, point_of_interest, establis...               525.0
#   14  [meal_takeaway, bar, restaurant, food, point_o...               115.0
#   15  [bar, restaurant, food, point_of_interest, est...               207.0
#   16  [restaurant, food, point_of_interest, establis...                 NaN
#   17  [restaurant, food, point_of_interest, establis...               755.0
#   18  [restaurant, food, point_of_interest, establis...               105.0
#   19  [bar, restaurant, food, point_of_interest, est...               210.0
#
#                                            vicinity
#   0                      19192 Colorado 8, Morrison
#   1                 301 Bear Creek Avenue, Morrison
#   2                 215 Bear Creek Avenue, Morrison
#   3                 316 Bear Creek Avenue, Morrison
#   4                13795 West Jewell Avenue, Denver
#   5   2950 S, Bear Creek Boulevard Unit A, Lakewood
#   6                 215 Bear Creek Avenue, Morrison
#   7            14011 West Quincy Avenue A, Morrison
#   8                 415 Bear Creek Avenue, Morrison
#   9                 109 Bear Creek Avenue, Morrison
#   10                    102 Market Street, Morrison
#   11                408 Bear Creek Avenue, Morrison
#   12           18300 West Alameda Parkway, Morrison
#   13      14011 West Quincy Avenue unit m, Morrison
#   14                401 Bear Creek Avenue, Morrison
#   15                     116 Stone Street, Morrison
#   16               3055 South Rooney Road, Morrison
#   17             14011 West Quincy Avenue, Morrison
#   18                     19192 Colorado 8, Morrison
#   19       13701 West Jewell Avenue # 103, Lakewood  }}

# %%
avg_price = []
avg_rating = []

for i in range(0,25):
    avg_price.append(zipcode_dict[i][i]['price_level'].mean())
    avg_rating.append(zipcode_dict[i][i]['rating'].mean())
restaurant_summary['Average Price']=avg_price
restaurant_summary['Average Rating']=avg_rating
restaurant_summary
# Out:
#       zip  latitude  longitude  Average Price  Average Rating
# 0   80002     39.79    -105.11       1.600000        4.170000
# 1   80003     39.83    -105.06       1.578947        3.975000
# 2   80004     39.82    -105.10       1.650000        4.075000
# 3   80005     39.85    -105.13       1.600000        4.125000
# 4   80031     39.88    -105.05       1.800000        4.030000
# 5   80033     39.77    -105.09       1.450000        4.005000
# 6   80110     39.64    -104.99       1.736842        4.120000
# 7   80123     39.62    -105.07       1.705882        4.005000
# 8   80127     39.57    -105.14       1.562500        3.942105
# 9   80128     39.56    -105.08       1.352941        3.980000
# 10  80204     39.73    -105.02       2.235294        4.405000
# 11  80211     39.77    -105.02       2.333333        4.400000
# 12  80212     39.77    -105.05       2.222222        4.431579
# 13  80214     39.74    -105.07       1.647059        4.055000
# 14  80215     39.74    -105.12       1.700000        3.975000
# 15  80219     39.70    -105.04       1.705882        4.045000
# 16  80221     39.82    -105.01       1.400000        3.940000
# 17  80226     39.71    -105.09       1.611111        3.825000
# 18  80227     39.67    -105.09       1.687500        4.000000
# 19  80228     39.69    -105.17       1.500000        3.965000
# 20  80232     39.69    -105.09       1.588235        3.780000
# 21  80236     39.65    -105.04       1.705882        3.985000
# 22  80401     39.73    -105.21       1.777778        4.240000
# 23  80454     39.62    -105.23       2.000000        4.471429
# 24  80465     39.65    -105.18       1.800000        4.189474

# %%
# Heatmaps
locations = restaurant_summary[['latitude','longitude']]
price = restaurant_summary['Average Price'].astype(float)
rating = restaurant_summary['Average Rating'].astype(float)
price_fig = gmaps.figure()
price_heat = gmaps.heatmap_layer(locations,weights=price,
                                dissipating=False,max_intensity=4,
                                point_radius=0.04)
price_fig.add_layer(price_heat)
rating_fig = gmaps.figure()
rating_heat = gmaps.heatmap_layer(locations,weights=rating,
                                dissipating=False,max_intensity=7.5,
                                point_radius=0.04,gradient=[(255,255,255,0.0),(255,0,0,0.5), (255,255,0,0.5), (0,255,0,0.5)])
rating_fig.add_layer(rating_heat)

# %%
# price map
price_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# rating map
rating_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
sorted_restaurants = restaurant_summary.sort_values(['Average Rating','Average Price'],ascending=[False,True])
sorted_restaurants.to_csv('../Resources/restaurants.csv')
sorted_restaurants
# Out:
#       zip  latitude  longitude  Average Price  Average Rating
# 23  80454     39.62    -105.23       2.000000        4.471429
# 12  80212     39.77    -105.05       2.222222        4.431579
# 10  80204     39.73    -105.02       2.235294        4.410000
# 11  80211     39.77    -105.02       2.333333        4.405000
# 22  80401     39.73    -105.21       1.777778        4.245000
# 24  80465     39.65    -105.18       1.800000        4.189474
# 0   80002     39.79    -105.11       1.600000        4.170000
# 3   80005     39.85    -105.13       1.600000        4.125000
# 6   80110     39.64    -104.99       1.736842        4.120000
# 2   80004     39.82    -105.10       1.650000        4.075000
# 13  80214     39.74    -105.07       1.647059        4.055000
# 15  80219     39.70    -105.04       1.705882        4.045000
# 4   80031     39.88    -105.05       1.800000        4.030000
# 5   80033     39.77    -105.09       1.450000        4.005000
# 7   80123     39.62    -105.07       1.705882        4.000000
# 18  80227     39.67    -105.09       1.687500        3.995000
# 9   80128     39.56    -105.08       1.352941        3.980000
# 1   80003     39.83    -105.06       1.578947        3.975000
# 14  80215     39.74    -105.12       1.700000        3.975000
# 21  80236     39.65    -105.04       1.705882        3.975000
# 19  80228     39.69    -105.17       1.500000        3.965000
# 16  80221     39.82    -105.01       1.400000        3.940000
# 8   80127     39.57    -105.14       1.562500        3.936842
# 17  80226     39.71    -105.09       1.611111        3.825000
# 20  80232     39.69    -105.09       1.588235        3.775000
